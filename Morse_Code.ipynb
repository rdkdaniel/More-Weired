# %% [markdown]
# <a href="https://colab.research.google.com/github/rdkdaniel/More-Weired/blob/main/Morse_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Represented using a combination of dots and dashes.
#Transmitted as a sound signal or light signal.
#The former uses two distint sounds (to rep the dots and dashes)
#The latter, uses short and long light periods (to rep the dots and dashes respectively)
#SOS is the easiest - in light it is three times short, three times long and three times short (peep scheme below for letter S and O)

# %% [markdown]
# ![International_Morse_Code.svg.png](data:image/png;base64,...)
